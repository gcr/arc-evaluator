# %% [markdown]
# # Bounding box illustration framework

# %%
import os
import simplejson
import skimage
from skimage import io
from matplotlib import pyplot as plt
import copy
import json
# %matplotlib inline

# %%
import PedestrianDataset
import bbox_utils
reload(bbox_utils)
reload(PedestrianDataset)

# %% [markdown]
# Load dataset dictionaries

# %%
bbox_lists_dict, img_dict = PedestrianDataset.load(bounding_box_folder = "TeamVision93/cpu")
bbox_lists_dict_truth, img_dict = PedestrianDataset.load(bounding_box_folder = "TeamVision93/groundTruth")

# %%
keys = bbox_lists_dict.keys()
key = keys[200]
img = bbox_utils.plot_bounding_box(img_dict[key],bbox_lists_dict[key],[1,1,1])
plt.imshow(img)
# Out:
# set07_V000_I01649

# %%
img = bbox_utils.plot_bounding_box(img_dict[key],bbox_lists_dict_truth[key],[1,1,1])
plt.imshow(img)
