# %% [markdown]
# # Bounding box evaluation framework

# %%
# %cd ~/notes/arc-challenge/
import os

import dataset
reload(dataset)
import CarDataset
reload(CarDataset)
import evaluation
reload(evaluation)
import bbox_utils
reload(bbox_utils)
from bbox_utils import BoundingBox
# Out:
# /store/home/michael/notes/arc-challenge

# %% [markdown]
# # UIUC Car data: Parsing student results

# %%
# %run plot_uiuc_cars.py
ax.legend_ = None
ax.legend(loc='upper left', bbox_to_anchor=(1,1))
fig
# Out:
# Loading data...
# Generating plots ...
# TODO: this should graph seconds per image
# TODO: this should graph seconds per image
# TODO: this should graph seconds per image
# TODO: this should graph seconds per image
# TODO: this should graph seconds per image
# TODO: this should graph seconds per image
# TODO: this should graph seconds per image
# TODO: this should graph seconds per image
# TODO: this should graph seconds per image

# %%
DenseMatrix1_CPU
# Out:
# {'test-0.png': [<Box: 15,45 + 118x45>],
#  'test-1.png': [<Box: 128,57 + 129x50>, <Box: 14,57 + 119x46>],
#  'test-10.png': [<Box: 26,24 + 126x48>,
#   <Box: -9,41 + 117x45>,
#   <Box: 99,40 + 112x43>],
#  'test-100.png': [<Box: -1,27 + 109x42>],
#  'test-101.png': [<Box: 8,13 + 111x43>],
#  'test-102.png': [<Box: -5,26 + 114x44>],
#  'test-103.png': [<Box: 41,87 + 123x47>, <Box: 35,132 + 135x52>],
#  'test-104.png': [<Box: -1,39 + 118x46>],
#  'test-105.png': [<Box: 26,58 + 114x44>, <Box: 130,62 + 109x42>],
#  'test-106.png': [<Box: 63,46 + 116x45>],
#  'test-107.png': [<Box: 15,38 + 118x45>,
#   <Box: 66,34 + 123x47>,
#   <Box: 36,0 + 109x42>],
#  'test-108.png': [<Box: 116,76 + 112x43>],
#  'test-109.png': [<Box: 64,-38 + 123x47>, <Box: 15,45 + 115x44>],
#  'test-11.png': [<Box: 94,37 + 117x45>, <Box: -13,38 + 110x42>],
#  'test-110.png': [<Box: 75,52 + 123x48>],
#  'test-111.png': [<Box: -11,22 + 116x45>],
#  'test-112.png': [<Box: 16,28 + 116x44>],
#  'test-113.png': [<Box: -10,50 + 115x44>, <Box: 84,48 + 124x48>],
#  'test-114.png': [<Box: 10,29 + 108x42>],
#  'test-115.png': [<Box: 58,64 + 110x42>, <Box: -4,103 + 112x43>],
#  'test-116.png': [<Box: 38,47 + 112x43>],
#  'test-117.png': [<Box: 124,78 + 116x44>, <Box: -1,74 + 120x46>],
#  'test-118.png': [<Box: 33,33 + 106x41>],
#  'test-119.png': [<Box: -2,14 + 113x43>],
#  'test-12.png': [<Box: 13,33 + 120x46>],
#  'test-120.png': [<Box: 8,12 + 119x46>],
#  'test-121.png': [<Box: 18,42 + 131x50>, <Box: 37,104 + 121x46>],
#  'test-122.png': [<Box: 89,51 + 124x48>,
#   <Box: -16,51 + 119x46>,
#   <Box: 14,100 + 122x47>,
#   <Box: 13,68 + 127x49>],
#  'test-123.png': [<Box: 4,22 + 115x44>],
#  'test-124.png': [<Box: 18,16 + 124x48>],
#  'test-125.png': [<Box: 22,35 + 121x46>],
#  'test-126.png': [<Box: 8,23 + 112x43>],
#  'test-127.png': [<Box: 26,38 + 115x44>],
#  'test-128.png': [<Box: 26,29 + 123x47>],
#  'test-129.png': [<Box: 111,68 + 116x45>, <Box: 154,144 + 130x50>],
#  'test-13.png': [<Box: 31,56 + 111x43>],
#  'test-130.png': [<Box: 29,38 + 113x43>,
#   <Box: -18,97 + 115x44>,
#   <Box: 22,113 + 118x45>],
#  'test-131.png': [<Box: 37,52 + 108x41>],
#  'test-132.png': [<Box: 125,79 + 122x47>,
#   <Box: 15,76 + 122x47>,
#   <Box: -18,159 + 115x44>,
#   <Box: 108,168 + 108x42>,
#   <Box: 160,168 + 106x41>],
#  'test-133.png': [<Box: 41,31 + 113x43>],
#  'test-134.png': [<Box: 25,13 + 116x44>],
#  'test-135.png': [<Box: 18,39 + 119x46>],
#  'test-136.png': [<Box: 10,22 + 114x44>],
#  'test-137.png': [<Box: 39,39 + 117x45>],
#  'test-138.png': [<Box: 41,38 + 111x43>],
#  'test-139.png': [<Box: -3,38 + 110x42>],
#  'test-14.png': [<Box: 72,51 + 116x45>],
#  'test-140.png': [<Box: -8,58 + 124x48>, <Box: 76,-19 + 125x48>],
#  'test-141.png': [<Box: 12,25 + 117x45>],
#  'test-142.png': [<Box: 8,38 + 113x43>, <Box: 54,32 + 144x55>],
#  'test-143.png': [<Box: 3,43 + 131x50>,
#   <Box: 109,42 + 133x51>,
#   <Box: 113,76 + 116x45>,
#   <Box: 105,94 + 137x53>],
#  'test-144.png': [<Box: -5,28 + 111x43>],
#  'test-145.png': [<Box: 14,31 + 118x46>],
#  'test-146.png': [<Box: 68,42 + 115x44>],
#  'test-147.png': [],
#  'test-148.png': [<Box: 28,36 + 109x42>],
#  'test-149.png': [<Box: 20,41 + 116x45>],
#  'test-15.png': [<Box: -1,53 + 122x47>,
#   <Box: 96,53 + 121x46>,
#   <Box: 190,54 + 124x48>],
#  'test-150.png': [<Box: 58,65 + 118x45>],
#  'test-151.png': [<Box: 14,37 + 116x45>],
#  'test-152.png': [<Box: 38,35 + 108x42>],
#  'test-153.png': [<Box: 16,30 + 119x46>, <Box: 95,78 + 113x43>],
#  'test-154.png': [<Box: 19,42 + 120x46>, <Box: 20,96 + 117x45>],
#  'test-155.png': [<Box: 41,46 + 116x44>, <Box: 46,88 + 110x42>],
#  'test-156.png': [<Box: 20,34 + 109x42>],
#  'test-157.png': [<Box: 15,38 + 114x44>],
#  'test-158.png': [<Box: 5,32 + 122x47>],
#  'test-159.png': [<Box: 10,73 + 119x46>],
#  'test-16.png': [<Box: 57,42 + 117x45>],
#  'test-160.png': [<Box: 62,31 + 117x45>],
#  'test-161.png': [<Box: 18,35 + 126x48>, <Box: 33,79 + 120x46>],
#  'test-162.png': [<Box: 44,21 + 120x46>],
#  'test-163.png': [<Box: 24,35 + 124x48>],
#  'test-164.png': [<Box: 42,41 + 116x45>],
#  'test-165.png': [<Box: 20,57 + 119x46>, <Box: 131,57 + 118x45>],
#  'test-166.png': [<Box: 18,39 + 119x46>],
#  'test-167.png': [<Box: 10,29 + 127x49>],
#  'test-168.png': [<Box: 90,-8 + 112x43>, <Box: 45,45 + 116x45>],
#  'test-169.png': [<Box: 25,43 + 117x45>,
#   <Box: 82,47 + 108x41>,
#   <Box: 28,86 + 106x41>],
#  'test-17.png': [<Box: 98,68 + 110x42>],
#  'test-18.png': [<Box: 15,102 + 115x44>, <Box: 253,107 + 116x45>],
#  'test-19.png': [<Box: 5,81 + 117x45>,
#   <Box: 108,82 + 113x43>,
#   <Box: 230,81 + 114x44>],
#  'test-2.png': [<Box: 48,21 + 118x45>],
#  'test-20.png': [<Box: 19,29 + 120x46>],
#  'test-21.png': [<Box: 58,48 + 120x46>],
#  'test-22.png': [<Box: 84,57 + 117x45>],
#  'test-23.png': [<Box: -17,37 + 118x45>],
#  'test-24.png': [<Box: 96,52 + 109x42>],
#  'test-25.png': [<Box: -18,31 + 121x47>],
#  'test-26.png': [<Box: 25,61 + 111x43>, <Box: 177,64 + 113x44>],
#  'test-27.png': [<Box: 30,42 + 119x46>],
#  'test-28.png': [<Box: 62,8 + 113x43>],
#  'test-29.png': [<Box: 49,44 + 119x46>],
#  'test-3.png': [<Box: 111,30 + 122x47>, <Box: 10,28 + 120x46>],
#  'test-30.png': [<Box: 21,31 + 120x46>],
#  'test-31.png': [<Box: -20,-32 + 111x43>, <Box: 20,39 + 112x43>],
#  'test-32.png': [<Box: 93,52 + 123x47>, <Box: -2,54 + 112x43>],
#  'test-33.png': [<Box: 46,28 + 115x44>],
#  'test-34.png': [<Box: 24,47 + 121x47>,
#   <Box: 19,77 + 127x49>,
#   <Box: 0,-4 + 109x42>],
#  'test-35.png': [<Box: 95,60 + 113x43>],
#  'test-36.png': [<Box: 7,44 + 116x45>],
#  'test-37.png': [<Box: 98,0 + 150x58>, <Box: 104,68 + 117x45>],
#  'test-38.png': [<Box: 39,51 + 114x44>],
#  'test-39.png': [<Box: 27,18 + 112x43>],
#  'test-4.png': [<Box: 106,40 + 118x45>, <Box: -1,40 + 114x44>],
#  'test-40.png': [<Box: 82,94 + 106x41>,
#   <Box: 173,93 + 107x41>,
#   <Box: 13,147 + 116x45>],
#  'test-41.png': [<Box: 15,27 + 119x46>],
#  'test-42.png': [<Box: -6,26 + 113x43>],
#  'test-43.png': [<Box: 11,23 + 107x41>, <Box: 11,62 + 106x41>],
#  'test-44.png': [<Box: 3,47 + 108x41>],
#  'test-45.png': [<Box: 32,52 + 116x44>],
#  'test-46.png': [<Box: 19,75 + 110x42>, <Box: 131,77 + 109x42>],
#  'test-47.png': [],
#  'test-48.png': [<Box: -2,31 + 115x44>],
#  'test-49.png': [<Box: 6,24 + 120x46>],
#  'test-5.png': [<Box: 40,-36 + 118x45>, <Box: 23,27 + 120x46>],
#  'test-50.png': [<Box: 13,32 + 123x47>, <Box: 82,-33 + 106x41>],
#  'test-51.png': [<Box: 13,31 + 120x46>],
#  'test-52.png': [<Box: 35,16 + 124x48>],
#  'test-53.png': [<Box: 28,29 + 123x47>],
#  'test-54.png': [<Box: 25,29 + 127x49>],
#  'test-55.png': [<Box: 26,22 + 120x46>],
#  'test-56.png': [<Box: 7,22 + 116x44>],
#  'test-57.png': [<Box: 43,55 + 120x46>],
#  'test-58.png': [<Box: 3,26 + 108x42>],
#  'test-59.png': [<Box: 201,62 + 115x44>],
#  'test-6.png': [<Box: -25,53 + 115x44>, <Box: 84,57 + 117x45>],
#  'test-60.png': [<Box: 24,42 + 119x46>],
#  'test-61.png': [<Box: 16,78 + 118x46>, <Box: 15,45 + 114x44>],
#  'test-62.png': [<Box: 26,26 + 112x43>],
#  'test-63.png': [<Box: 36,33 + 117x45>],
#  'test-64.png': [<Box: 91,52 + 112x43>],
#  'test-65.png': [<Box: 33,40 + 123x47>],
#  'test-66.png': [<Box: 20,59 + 125x48>, <Box: 123,62 + 124x48>],
#  'test-67.png': [<Box: 9,22 + 116x45>],
#  'test-68.png': [<Box: 110,58 + 115x44>, <Box: -3,54 + 118x45>],
#  'test-69.png': [<Box: 18,35 + 124x48>],
#  'test-7.png': [<Box: 118,57 + 117x45>, <Box: -10,54 + 116x45>],
#  'test-70.png': [<Box: -9,36 + 119x46>],
#  'test-71.png': [<Box: 42,34 + 119x46>],
#  'test-72.png': [<Box: 37,-46 + 149x57>,
#   <Box: -8,30 + 124x48>,
#   <Box: 62,41 + 125x48>],
#  'test-73.png': [<Box: 0,49 + 121x47>],
#  'test-74.png': [<Box: 77,60 + 114x44>],
#  'test-75.png': [<Box: 47,54 + 118x46>],
#  'test-76.png': [<Box: 56,42 + 124x48>],
#  'test-77.png': [<Box: 19,16 + 106x41>],
#  'test-78.png': [<Box: 14,31 + 113x43>, <Box: 12,76 + 109x42>],
#  'test-79.png': [<Box: 35,41 + 114x44>],
#  'test-8.png': [<Box: 53,46 + 113x43>],
#  'test-80.png': [<Box: 53,58 + 118x46>],
#  'test-81.png': [<Box: -11,68 + 116x44>, <Box: 113,55 + 112x43>],
#  'test-82.png': [<Box: -7,44 + 166x64>, <Box: 94,62 + 116x45>],
#  'test-83.png': [<Box: 27,36 + 109x42>],
#  'test-84.png': [<Box: 60,36 + 117x45>],
#  'test-85.png': [<Box: 9,48 + 118x45>],
#  'test-86.png': [<Box: 32,68 + 116x44>, <Box: 149,66 + 123x48>],
#  'test-87.png': [<Box: 0,54 + 110x42>, <Box: 85,-20 + 130x50>],
#  'test-88.png': [<Box: 60,121 + 152x59>, <Box: 75,69 + 127x49>],
#  'test-89.png': [<Box: 16,47 + 111x43>],
#  'test-9.png': [<Box: -10,23 + 120x46>, <Box: 99,26 + 112x43>],
#  'test-90.png': [<Box: 77,57 + 118x46>],
#  'test-91.png': [<Box: -12,-25 + 161x62>, <Box: 65,40 + 115x44>],
#  'test-92.png': [<Box: -7,52 + 122x47>],
#  'test-93.png': [<Box: -28,-56 + 182x70>,
#   <Box: 3,89 + 145x56>,
#   <Box: -6,-21 + 136x52>,
#   <Box: 75,52 + 111x43>],
#  'test-94.png': [<Box: 14,41 + 115x44>],
#  'test-95.png': [<Box: 67,50 + 130x50>,
#   <Box: 76,103 + 128x49>,
#   <Box: 76,72 + 110x42>],
#  'test-96.png': [<Box: 8,47 + 112x43>],
#  'test-97.png': [<Box: 90,73 + 119x46>],
#  'test-98.png': [<Box: 113,49 + 113x43>,
#   <Box: 90,8 + 106x41>,
#   <Box: -7,48 + 109x42>],
#  'test-99.png': [<Box: -15,22 + 114x44>, <Box: 78,102 + 106x41>]}

# %% [markdown]
# # Pedestrian data (WIP, BROKEN)

# %%
import PedestrianDataset
reload(PedestrianDataset)

bbox_lists_dict, img_dict = PedestrianDataset.load(bounding_box_folder = "StudentData-Caltech-Pedestrians/TeamVision93/cpu")
bbox_lists_dict_truth, img_dict = PedestrianDataset.load(bounding_box_folder = "StudentData-Caltech-Pedestrians/TeamVision93/groundTruth")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-211-d987b4d20693> in <module>()
#       2 reload(PedestrianDataset)
#       3
# ----> 4 bbox_lists_dict, img_dict = PedestrianDataset.load(bounding_box_folder = "StudentData-Caltech-Pedestrians/TeamVision93/cpu")
#       5 bbox_lists_dict_truth, img_dict = PedestrianDataset.load(bounding_box_folder = "StudentData-Caltech-Pedestrians/TeamVision93/groundTruth")
#
# /store/home/michael/notes/arc-challenge/PedestrianDataset.pyc in load(bounding_box_folder)
#      13     bbbox_lists_dict = {}
#      14
# ---> 15     for file in os.listdir(img_folder):
#      16         img_file_dict[os.path.splitext(file)[0]] = img_folder +"/"+ file
#      17
#
# OSError: [Errno 2] No such file or directory: 'TeamVision93/images'

# %%
# %%time
fig,ax = subplots()
reload(evaluation)

evaluation.make_accuracy_plot(
    ax,
    bbox_lists_dict_truth, bbox_lists_dict_truth, bbox_lists_dict, evaluation.HPU_strategy_random_mix,
    label="Team Vision93, Experiment-1\nRandom mix of Groundtruth+CPU",
    match_mode="iou",
    N=1,
    num_graph_points=10,
)
ax.set_title("HPU+CPU Hybrid Accuracy")
ax.legend(loc='upper left', bbox_to_anchor=(1,1))
# Out:
# TODO: this should graph seconds per image
# CPU times: user 50.5 s, sys: 57 ms, total: 50.5 s
# Wall time: 51.9 s

# %%
reload(evaluation)
evaluation.make_accuracy_plot(
    ax,
    bbox_lists_dict_truth, bbox_lists_dict_truth, bbox_lists_dict, evaluation.HPU_strategy_increasing_lowest_confidence_mix,
    label="Team Vision93, Experiment-1\nRandom mix of Groundtruth+CPU",
    match_mode="iou",
    N=1,
    num_graph_points=10,
)
